# %% [markdown]
# <a href="https://colab.research.google.com/github/huavanson/CS114.K21/blob/master/Lab05(edited).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6d2dd9d4-fb2e-4f17-9b3d-78ef9132a99f" name="files[]" multiple disabled />
#      <output id="result-6d2dd9d4-fb2e-4f17-9b3d-78ef9132a99f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"sonhuavan","key":"899cfa81c0f3f4051aee96eb7e74b10f"}'}

# %%
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 65 Apr  6 07:35 kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s face
# Out:
# ...
# ref                                                          title                                                size  lastUpdated          downloadCount
# -----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# dataturks/face-detection-in-images                           Face Detection in Images                             55KB  2018-07-12 09:34:14           5140
# splcher/animefacedataset                                     Anime Face Dataset                                  395MB  2019-10-13 16:33:20            564
# atulanandjha/lfwpeople                                       LFW - People (Face Recognition)                     232MB  2019-11-15 19:45:43           1827
# ciplab/real-and-fake-face-detection                          Real and Fake Face Detection                        431MB  2019-01-14 14:54:52           2315
# ...

# %%
# !kaggle datasets download -d stackoverflow/stack-overflow-2018-developer-survey
# Out:
# ...
#  61% 12.0M/19.6M [00:00<00:00, 108MB/s]
# 100% 19.6M/19.6M [00:00<00:00, 96.0MB/s]

# %%
# !unzip stack-overflow-2018-developer-survey.zip
# Out:
# Archive:  stack-overflow-2018-developer-survey.zip
#   inflating: survey_results_public.csv
#   inflating: survey_results_schema.csv

# %%
import pandas as pd
d=pd.read_csv('survey_results_public.csv')
d.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Respondent Hobby  ...                         SurveyTooLong     SurveyEasy
# 0           1   Yes  ...  The survey was an appropriate length      Very easy
# 1           3   Yes  ...  The survey was an appropriate length  Somewhat easy
# 2           4   Yes  ...                                   NaN            NaN
# 3           5    No  ...  The survey was an appropriate length  Somewhat easy
# 4           7   Yes  ...  The survey was an appropriate length  Somewhat easy
#
# ...
